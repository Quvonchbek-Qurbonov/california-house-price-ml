# %%
import kagglehub
import os

# Download latest version
path = kagglehub.dataset_download("camnugent/california-housing-prices", output_dir=os.getcwd()+"/app/dataset")

# %%
import pandas as pd

data = pd.read_csv(path+'/housing.csv')
data.head()
